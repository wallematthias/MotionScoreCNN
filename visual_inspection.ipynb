# %%
from motionscore.motionscore import main
main(option='confirm')
# Out:
# Graded 259 out of 284 images. 25 images remaining.
# Enter your assessment for the motion score [2]:
# Grading completed. Graded data saved to '/home/matthias.walle/data/test/grades.csv'.
# Accuracy: 100.00%
