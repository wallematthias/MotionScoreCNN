# %%
from motionscore.motionscore import main
main(option='confirm')
# Out:
# Graded 103 out of 104 images. 1 images remaining.
# Enter your assessment for the motion score [5]:
# Grading completed. Graded data saved to '/home/matthias.walle/data/test/grades.csv'.
# Accuracy: 100.00%
